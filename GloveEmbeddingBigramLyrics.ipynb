# %% [markdown]
# ## imports

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
# from keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Embedding
from tensorflow.keras.utils import to_categorical
from  tensorflow.keras.preprocessing import text_dataset_from_directory
import numpy
from keras.preprocessing.sequence import pad_sequences
import os
import numpy
from keras.preprocessing.sequence import pad_sequences

# from tensorflow.keras.metrics import

# %% [markdown]
#  ## methods to get data

# %%
def importData(directory: str) -> list:
    with open(directory) as f:
        return f.read()

def getAllFilesInFolder(dir: str) -> list:
    return os.listdir(dir)

# %% [markdown]
# ## load all of the country music data into memory

# %%
songs = []
for file in getAllFilesInFolder("./data/Country"):
    filePath = "./data/Country/{}".format(file)
    if "DS_Store" not in filePath:
        songs.append(importData(filePath))

len(songs)
# Out:
# 100

# %% [markdown]
# ## turn each word in text into integer-index representation

# %%
# integer encode text
tokenizer = Tokenizer()
tokenizer.fit_on_texts(songs)
vocab_size = len(tokenizer.word_index) + 1
print('Vocabulary Size: %d' % vocab_size)

# Transforms each text in texts to a sequence of integers.
encoded = tokenizer.texts_to_sequences(songs)
len(encoded)
# Out:
# Vocabulary Size: 2803
# 100

# %% [markdown]
# ## get all of the triples and thier target word in the music data

# %%
# create word -> word sequences 
# get sequences of words together, so given "a b c d e"
#  you should give [a,b,c,d], [b,c,d,e] adn all the adjacent triples and thier target word
sequences = []
for i in range(len(encoded)):
	for j in range(2, len(encoded[i])):
		sequence = encoded[i][j-2:j+1]
		sequences.append(sequence)
		
		
print('Total Sequences: %d' % len(sequences))
sequences
# Out:
# Total Sequences: 25367
# [[2, 458, 14],
#  [458, 14, 516],
#  [14, 516, 2],
#  [516, 2, 32],
#  [2, 32, 408],
#  [32, 408, 3],
#  [408, 3, 5],
#  [3, 5, 459],
#  [5, 459, 460],
#  [459, 460, 1439],
#  [460, 1439, 34],
#  [1439, 34, 1],
#  [34, 1, 161],
#  [1, 161, 118],
#  [161, 118, 169],
#  [118, 169, 18],
#  [169, 18, 5],
#  [18, 5, 43],
#  [5, 43, 320],
#  [43, 320, 112],
#  [320, 112, 1440],
#  [112, 1440, 3],
#  [1440, 3, 89],
#  [3, 89, 3],
#  [89, 3, 169],
#  [3, 169, 94],
#  [169, 94, 38],
#  [94, 38, 110],
#  [38, 110, 4],
#  [110, 4, 95],
#  [4, 95, 110],
#  [95, 110, 156],
#  [110, 156, 95],
#  [156, 95, 58],
#  [95, 58, 2],
#  [58, 2, 458],
#  [2, 458, 14],
#  [458, 14, 516],
#  [14, 516, 2],
#  [516, 2, 32],
#  [2, 32, 408],
#  [32, 408, 3],
#  [408, 3, 5],
#  [3, 5, 459],
#  [5, 459, 1104],
#  [459, 1104, 73],
#  [1104, 73, 261],
#  [73, 261, 3],
#  [261, 3, 178],
#  [3, 178, 29],
#  [178, 29, 188],
#  [29, 188, 1105],
#  [188, 1105, 1441],
#  [1105, 1441, 19],
#  [1441, 19, 3],
#  [19, 3, 23],
#  [3, 23, 116],
#  [23, 116, 611],
#  [116, 611, 1442],
#  [611, 1442, 12],
#  [1442, 12, 1443],
#  [12, 1443, 11],
#  [1443, 11, 1444],
#  [11, 1444, 38],
#  [1444, 38, 3],
#  [38, 3, 111],
#  [3, 111, 65],
#  [111, 65, 13],
#  [65, 13, 1445],
#  [13, 1445, 30],
#  [1445, 30, 166],
#  [30, 166, 858],
#  [166, 858, 3],
#  [858, 3, 73],
#  [3, 73, 55],
#  [73, 55, 13],
#  [55, 13, 124],
#  [13, 124, 170],
#  [124, 170, 2],
#  [170, 2, 104],
#  [2, 104, 94],
#  [104, 94, 3],
#  [94, 3, 1],
#  [3, 1, 64],
#  [1, 64, 96],
#  [64, 96, 53],
#  [96, 53, 12],
#  [53, 12, 5],
#  [12, 5, 859],
#  [5, 859, 1446],
#  [859, 1446, 19],
#  [1446, 19, 67],
#  [19, 67, 104],
#  [67, 104, 13],
#  [104, 13, 1447],
#  [13, 1447, 150],
#  [1447, 150, 17],
#  [150, 17, 5],
#  [17, 5, 179],
#  [5, 179, 4],
#  [179, 4, 461],
#  [4, 461, 18],
#  [461, 18, 1106],
#  [18, 1106, 16],
#  [1106, 16, 860],
#  [16, 860, 18],
#  [860, 18, 38],
#  [18, 38, 1107],
#  [38, 1107, 124],
#  [1107, 124, 180],
#  [124, 180, 4],
#  [180, 4, 1108],
#  [4, 1108, 1],
#  [1108, 1, 59],
#  [1, 59, 370],
#  [59, 370, 179],
#  [370, 179, 25],
#  [179, 25, 1109],
#  [25, 1109, 458],
#  [1109, 458, 14],
#  [458, 14, 516],
#  [14, 516, 2],
#  [516, 2, 32],
#  [2, 32, 408],
#  [32, 408, 3],
#  [408, 3, 5],
#  [3, 5, 459],
#  [5, 459, 460],
#  [459, 460, 180],
#  [460, 180, 34],
#  [180, 34, 1],
#  [34, 1, 161],
#  [1, 161, 118],
#  [161, 118, 169],
#  [118, 169, 18],
#  [169, 18, 5],
#  [18, 5, 43],
#  [5, 43, 320],
#  [43, 320, 112],
#  [320, 112, 40],
#  [112, 40, 2],
#  [40, 2, 458],
#  [2, 458, 14],
#  [458, 14, 516],
#  [14, 516, 2],
#  [516, 2, 32],
#  [2, 32, 408],
#  [32, 408, 3],
#  [408, 3, 5],
#  [3, 5, 459],
#  [5, 459, 1104],
#  [459, 1104, 73],
#  [1104, 73, 262],
#  [73, 262, 3],
#  [262, 3, 5],
#  [3, 5, 1448],
#  [5, 1448, 4],
#  [1448, 4, 261],
#  [4, 261, 3],
#  [261, 3, 1],
#  [3, 1, 517],
#  [1, 517, 19],
#  [517, 19, 30],
#  [19, 30, 139],
#  [30, 139, 67],
#  [139, 67, 13],
#  [67, 13, 518],
#  [13, 518, 6],
#  [518, 6, 162],
#  [6, 162, 3],
#  [162, 3, 129],
#  [3, 129, 21],
#  [129, 21, 37],
#  [21, 37, 519],
#  [37, 519, 95],
#  [519, 95, 3],
#  [95, 3, 58],
#  [3, 58, 19],
#  [58, 19, 118],
#  [19, 118, 33],
#  [118, 33, 189],
#  [33, 189, 2],
#  [189, 2, 80],
#  [2, 80, 3],
#  [80, 3, 6],
#  [3, 6, 1449],
#  [6, 1449, 111],
#  [1449, 111, 171],
#  [111, 171, 181],
#  [171, 181, 3],
#  [181, 3, 1450],
#  [3, 1450, 108],
#  [1450, 108, 1110],
#  [108, 1110, 371],
#  [1110, 371, 341],
#  [371, 341, 4],
#  [341, 4, 90],
#  [4, 90, 210],
#  [90, 210, 69],
#  [210, 69, 18],
#  [69, 18, 299],
#  [18, 299, 90],
#  [299, 90, 6],
#  [90, 6, 1451],
#  [6, 1451, 3],
#  [1451, 3, 71],
#  [3, 71, 4],
#  [71, 4, 3],
#  [4, 3, 24],
#  [3, 24, 67],
#  [24, 67, 20],
#  [67, 20, 858],
#  [20, 858, 1452],
#  [858, 1452, 150],
#  [1452, 150, 17],
#  [150, 17, 5],
#  [17, 5, 179],
#  [5, 179, 4],
#  [179, 4, 461],
#  [4, 461, 18],
#  [461, 18, 1106],
#  [18, 1106, 16],
#  [1106, 16, 860],
#  [16, 860, 18],
#  [860, 18, 38],
#  [18, 38, 1107],
#  [38, 1107, 124],
#  [1107, 124, 180],
#  [124, 180, 4],
#  [180, 4, 1108],
#  [4, 1108, 1],
#  [1108, 1, 59],
#  [1, 59, 370],
#  [59, 370, 179],
#  [370, 179, 25],
#  [179, 25, 1109],
#  [25, 1109, 458],
#  [1109, 458, 14],
#  [458, 14, 516],
#  [14, 516, 2],
#  [516, 2, 32],
#  [2, 32, 408],
#  [32, 408, 3],
#  [408, 3, 5],
#  [3, 5, 459],
#  [5, 459, 460],
#  [459, 460, 180],
#  [460, 180, 34],
#  [180, 34, 1],
#  [34, 1, 161],
#  [1, 161, 118],
#  [161, 118, 169],
#  [118, 169, 18],
#  [169, 18, 5],
#  [18, 5, 43],
#  [5, 43, 320],
#  [43, 320, 112],
#  [320, 112, 40],
#  [112, 40, 2],
#  [40, 2, 458],
#  [2, 458, 14],
#  [458, 14, 516],
#  [14, 516, 2],
#  [516, 2, 32],
#  [2, 32, 408],
#  [32, 408, 3],
#  [408, 3, 5],
#  [3, 5, 459],
#  [5, 459, 460],
#  [459, 460, 180],
#  [460, 180, 34],
#  [180, 34, 1],
#  [34, 1, 161],
#  [77, 41, 7],
#  [41, 7, 612],
#  [7, 612, 1111],
#  [612, 1111, 321],
#  [1111, 321, 77],
#  [321, 77, 41],
#  [77, 41, 1112],
#  [41, 1112, 131],
#  [1112, 131, 1453],
#  [131, 1453, 7],
#  [1453, 7, 1454],
#  [7, 1454, 1455],
#  [1454, 1455, 52],
#  [1455, 52, 3],
#  [52, 3, 38],
#  [3, 38, 861],
#  [38, 861, 127],
#  [861, 127, 2],
#  [127, 2, 113],
#  [2, 113, 233],
#  [113, 233, 3],
#  [233, 3, 44],
#  [3, 44, 4],
#  [44, 4, 300],
#  [4, 300, 862],
#  [300, 862, 38],
#  [862, 38, 1456],
#  [38, 1456, 115],
#  [1456, 115, 40],
#  [115, 40, 2],
#  [40, 2, 63],
#  [2, 63, 6],
#  [63, 6, 162],
#  [6, 162, 862],
#  [162, 862, 41],
#  [862, 41, 7],
#  [41, 7, 1457],
#  [7, 1457, 4],
#  [1457, 4, 20],
#  [4, 20, 14],
#  [20, 14, 16],
#  [14, 16, 1458],
#  [16, 1458, 2],
#  [1458, 2, 23],
#  [2, 23, 322],
#  [23, 322, 68],
#  [322, 68, 462],
#  [68, 462, 15],
#  [462, 15, 7],
#  [15, 7, 1459],
#  [7, 1459, 280],
#  [1459, 280, 52],
#  [280, 52, 41],
#  [52, 41, 7],
#  [41, 7, 15],
#  [7, 15, 40],
#  [15, 40, 222],
#  [40, 222, 715],
#  [222, 715, 8],
#  [715, 8, 96],
#  [8, 96, 44],
#  [96, 44, 144],
#  [44, 144, 1],
#  [144, 1, 247],
#  [1, 247, 20],
#  [247, 20, 14],
#  [20, 14, 716],
#  [14, 716, 78],
#  [716, 78, 4],
#  [78, 4, 2],
#  [4, 2, 23],
#  [2, 23, 113],
#  [23, 113, 62],
#  [113, 62, 124],
#  [62, 124, 48],
#  [124, 48, 42],
#  [48, 42, 3],
#  [42, 3, 409],
#  [3, 409, 29],
#  [409, 29, 248],
#  [29, 248, 3],
#  [248, 3, 163],
#  [3, 163, 7],
#  [163, 7, 863],
#  [7, 863, 96],
#  [863, 96, 6],
#  [96, 6, 864],
#  [6, 864, 42],
#  [864, 42, 3],
#  [42, 3, 55],
#  [3, 55, 8],
#  [55, 8, 105],
#  [8, 105, 38],
#  [105, 38, 96],
#  [38, 96, 280],
#  [96, 280, 52],
#  [280, 52, 41],
#  [52, 41, 7],
#  [41, 7, 15],
#  [7, 15, 40],
#  [15, 40, 1460],
#  [40, 1460, 21],
#  [1460, 21, 33],
#  [21, 33, 194],
#  [33, 194, 74],
#  [194, 74, 3],
#  [74, 3, 27],
#  [3, 27, 21],
#  [27, 21, 140],
#  [21, 140, 6],
#  [140, 6, 55],
#  [6, 55, 8],
#  [55, 8, 124],
#  [8, 124, 1461],
#  [124, 1461, 3],
#  [1461, 3, 31],
#  [3, 31, 112],
#  [31, 112, 1462],
#  [112, 1462, 865],
#  [1462, 865, 4],
#  [865, 4, 2],
#  [4, 2, 21],
#  [2, 21, 70],
#  [21, 70, 63],
#  [70, 63, 1463],
#  [63, 1463, 280],
#  [1463, 280, 52],
#  [280, 52, 41],
#  [52, 41, 7],
#  [41, 7, 15],
#  [7, 15, 40],
#  [15, 40, 222],
#  [40, 222, 715],
#  [222, 715, 8],
#  [715, 8, 96],
#  [8, 96, 44],
#  [96, 44, 144],
#  [44, 144, 1],
#  [144, 1, 247],
#  [1, 247, 20],
#  [247, 20, 14],
#  [20, 14, 716],
#  [14, 716, 78],
#  [716, 78, 4],
#  [78, 4, 2],
#  [4, 2, 23],
#  [2, 23, 113],
#  [23, 113, 62],
#  [113, 62, 124],
#  [62, 124, 48],
#  [124, 48, 42],
#  [48, 42, 3],
#  [42, 3, 409],
#  [3, 409, 29],
#  [409, 29, 248],
#  [29, 248, 3],
#  [248, 3, 163],
#  [3, 163, 7],
#  [163, 7, 863],
#  [7, 863, 96],
#  [863, 96, 6],
#  [96, 6, 864],
#  [6, 864, 42],
#  [864, 42, 3],
#  [42, 3, 55],
#  [3, 55, 8],
#  [55, 8, 105],
#  [8, 105, 38],
#  [105, 38, 96],
#  [38, 96, 280],
#  [96, 280, 52],
#  [280, 52, 41],
#  [52, 41, 7],
#  [41, 7, 15],
#  [7, 15, 40],
#  [15, 40, 1464],
#  [40, 1464, 52],
#  [1464, 52, 151],
#  [52, 151, 69],
#  [151, 69, 18],
#  [69, 18, 42],
#  [18, 42, 1],
#  [42, 1, 119],
#  [1, 119, 1465],
#  [119, 1465, 2],
#  [1465, 2, 1466],
#  [2, 1466, 280],
#  [1466, 280, 52],
#  [280, 52, 41],
#  [52, 41, 7],
#  [41, 7, 15],
#  [7, 15, 40],
#  [15, 40, 222],
#  [40, 222, 715],
#  [222, 715, 8],
#  [715, 8, 96],
#  [8, 96, 44],
#  [96, 44, 144],
#  [44, 144, 1],
#  [144, 1, 247],
#  [1, 247, 20],
#  [247, 20, 14],
#  [20, 14, 716],
#  [14, 716, 78],
#  [716, 78, 4],
#  [78, 4, 2],
#  [4, 2, 23],
#  [2, 23, 113],
#  [23, 113, 62],
#  [113, 62, 124],
#  [62, 124, 48],
#  [124, 48, 42],
#  [48, 42, 3],
#  [42, 3, 409],
#  [3, 409, 29],
#  [409, 29, 248],
#  [29, 248, 3],
#  [248, 3, 163],
#  [3, 163, 7],
#  [163, 7, 863],
#  [7, 863, 96],
#  [863, 96, 6],
#  [96, 6, 864],
#  [6, 864, 42],
#  [864, 42, 3],
#  [42, 3, 55],
#  [3, 55, 8],
#  [55, 8, 105],
#  [8, 105, 38],
#  [105, 38, 96],
#  [38, 96, 1],
#  [96, 1, 91],
#  [1, 91, 2],
#  [91, 2, 1467],
#  [2, 1467, 3],
#  [1467, 3, 27],
#  [3, 27, 1],
#  [27, 1, 91],
#  [1, 91, 2],
#  [91, 2, 234],
#  [2, 234, 280],
#  [234, 280, 52],
#  [280, 52, 41],
#  [52, 41, 7],
#  [41, 7, 15],
#  [7, 15, 40],
#  [15, 40, 222],
#  [40, 222, 77],
#  [222, 77, 52],
#  [77, 52, 41],
#  [52, 41, 7],
#  [41, 7, 15],
#  [7, 15, 40],
#  [15, 40, 222],
#  [40, 222, 4],
#  [222, 4, 2],
#  [4, 2, 23],
#  [2, 23, 62],
#  [23, 62, 113],
#  [62, 113, 124],
#  [113, 124, 48],
#  [74, 1, 1468],
#  [1, 1468, 342],
#  [1468, 342, 195],
#  [342, 195, 47],
#  [195, 47, 1113],
#  [47, 1113, 1469],
#  [1113, 1469, 717],
#  [1469, 717, 1470],
#  [717, 1470, 9],
#  [1470, 9, 1],
#  [9, 1, 1471],
#  [1, 1471, 11],
#  [1471, 11, 1],
#  [11, 1, 1472],
#  [1, 1472, 1473],
#  [1472, 1473, 66],
#  [1473, 66, 1474],
#  [66, 1474, 47],
#  [1474, 47, 1475],
#  [47, 1475, 44],
#  [1475, 44, 1114],
#  [44, 1114, 1476],
#  [1114, 1476, 1],
#  [1476, 1, 1477],
#  [1, 1477, 195],
#  [1477, 195, 4],
#  [195, 4, 26],
#  [4, 26, 2],
#  [26, 2, 866],
#  [2, 866, 47],
#  [866, 47, 520],
#  [47, 520, 7],
#  [520, 7, 867],
#  [7, 867, 718],
#  [867, 718, 34],
#  [718, 34, 1478],
#  [34, 1478, 1],
#  [1478, 1, 1479],
#  [1, 1479, 1480],
#  [1479, 1480, 410],
#  [1480, 410, 5],
#  [410, 5, 1481],
#  [5, 1481, 859],
#  [1481, 859, 517],
#  [859, 517, 2],
#  [517, 2, 281],
#  [2, 281, 1482],
#  [281, 1482, 34],
#  [1482, 34, 1],
#  [34, 1, 235],
#  [1, 235, 6],
#  [235, 6, 613],
#  [6, 613, 1],
#  [613, 1, 1483],
#  [1, 1483, 1484],
#  [1483, 1484, 4],
#  [1484, 4, 1485],
#  [4, 1485, 1486],
#  [1485, 1486, 1487],
#  [1486, 1487, 8],
#  [1487, 8, 1],
#  [8, 1, 1113],
#  [1, 1113, 868],
#  [1113, 868, 614],
#  [868, 614, 2],
#  [614, 2, 615],
#  [2, 615, 48],
#  [615, 48, 6],
#  [48, 6, 1],
#  [6, 1, 1488],
#  [1, 1488, 1489],
#  [1488, 1489, 4],
#  [1489, 4, 301],
#  [4, 301, 1],
#  [301, 1, 1490],
#  [1, 1490, 1491],
#  [1490, 1491, 1],
#  [1491, 1, 249],
#  [1, 249, 211],
#  [249, 211, 1492],
#  [211, 1492, 1],
#  [1492, 1, 1493],
#  [1, 1493, 4],
#  [1493, 4, 1],
#  [4, 1, 1494],
#  [1, 1494, 1495],
#  [1494, 1495, 1],
#  [1495, 1, 372],
#  [1, 372, 1496],
#  [372, 1496, 85],
#  [1496, 85, 124],
#  [85, 124, 6],
#  [124, 6, 1497],
#  [6, 1497, 103],
#  [1497, 103, 14],
#  [103, 14, 869],
#  [14, 869, 4],
#  [869, 4, 1498],
#  [4, 1498, 34],
#  [1498, 34, 8],
#  [34, 8, 521],
#  [8, 521, 616],
#  [521, 616, 1],
#  [616, 1, 1499],
#  [1, 1499, 302],
#  [1499, 302, 4],
#  [302, 4, 1],
#  [4, 1, 323],
#  [1, 323, 85],
#  [323, 85, 18],
#  [85, 18, 14],
#  [18, 14, 145],
#  [14, 145, 4],
#  [145, 4, 1],
#  [4, 1, 235],
#  [1, 235, 85],
#  [235, 85, 18],
#  [85, 18, 7],
#  [18, 7, 617],
#  [522, 27, 411],
#  [27, 411, 212],
#  [411, 212, 10],
#  [212, 10, 97],
#  [10, 97, 1500],
#  [97, 1500, 78],
#  [1500, 78, 27],
#  [78, 27, 86],
#  [27, 86, 9],
#  [86, 9, 1501],
#  [9, 1501, 71],
#  [1501, 71, 12],
#  [71, 12, 1502],
#  [12, 1502, 78],
#  [1502, 78, 2],
#  [78, 2, 49],
#  [2, 49, 100],
#  [49, 100, 1],
#  [100, 1, 1503],
#  [1, 1503, 71],
#  [1503, 71, 4],
#  [71, 4, 1],
#  [4, 1, 870],
#  [1, 870, 233],
#  [870, 233, 9],
#  [233, 9, 78],
#  [9, 78, 21],
#  [78, 21, 29],
#  [21, 29, 5],
#  [29, 5, 50],
#  [5, 50, 182],
#  [50, 182, 172],
#  [182, 172, 3],
#  [172, 3, 99],
#  [3, 99, 303],
#  [99, 303, 9],
#  [303, 9, 5],
#  [9, 5, 179],
#  [5, 179, 4],
#  [179, 4, 70],
#  [4, 70, 343],
#  [70, 343, 19],
#  [343, 19, 1504],
#  [19, 1504, 22],
#  [1504, 22, 132],
#  [22, 132, 719],
#  [132, 719, 412],
#  [719, 412, 12],
#  [412, 12, 1],
#  [12, 1, 871],
#  [1, 871, 463],
#  [871, 463, 16],
#  [463, 16, 4],
#  [16, 4, 203],
#  [4, 203, 97],
#  [203, 97, 720],
#  [97, 720, 721],
#  [720, 721, 872],
#  [721, 872, 4],
#  [872, 4, 5],
#  [4, 5, 873],
#  [5, 873, 4],
#  [873, 4, 5],
#  [4, 5, 874],
#  [5, 874, 875],
#  [874, 875, 282],
#  [875, 282, 12],
#  [282, 12, 1],
#  [12, 1, 876],
#  [1, 876, 146],
#  [876, 146, 12],
#  [146, 12, 1],
#  [12, 1, 263],
#  [1, 263, 262],
#  [263, 262, 180],
#  [262, 180, 128],
#  [180, 128, 22],
#  [128, 22, 33],
#  [22, 33, 25],
#  [33, 25, 24],
#  [25, 24, 22],
#  [24, 22, 5],
#  [22, 5, 150],
#  [5, 150, 22],
#  [150, 22, 5],
#  [22, 5, 194],
#  [5, 194, 22],
#  [194, 22, 5],
#  [22, 5, 877],
#  [5, 877, 11],
#  [877, 11, 413],
#  [11, 413, 22],
#  [413, 22, 522],
#  [22, 522, 166],
#  [522, 166, 1505],
#  [166, 1505, 283],
#  [1505, 283, 1506],
#  [283, 1506, 48],
#  [1506, 48, 87],
#  [48, 87, 1],
#  [87, 1, 1507],
#  [1, 1507, 4],
#  [1507, 4, 1508],
#  [4, 1508, 19],
#  [1508, 19, 10],
#  [19, 10, 1509],
#  [10, 1509, 722],
#  [1509, 722, 22],
#  [722, 22, 523],
#  [22, 523, 4],
#  [523, 4, 1510],
#  [4, 1510, 1511],
#  [1510, 1511, 1115],
#  [1511, 1115, 19],
#  [1115, 19, 1],
#  [19, 1, 1512],
#  [1, 1512, 524],
#  [1512, 524, 108],
#  [524, 108, 1513],
#  [108, 1513, 5],
#  [1513, 5, 1116],
#  [5, 1116, 26],
#  [1116, 26, 125],
#  [26, 125, 1117],
#  [125, 1117, 1514],
#  [1117, 1514, 196],
#  [1514, 196, 125],
#  [196, 125, 97],
#  [125, 97, 1515],
#  [97, 1515, 22],
#  [1515, 22, 132],
#  [22, 132, 719],
#  [132, 719, 412],
#  [719, 412, 12],
#  [412, 12, 1],
#  [12, 1, 871],
#  [1, 871, 463],
#  [871, 463, 16],
#  [463, 16, 4],
#  [16, 4, 203],
#  [4, 203, 97],
#  [203, 97, 720],
#  [97, 720, 721],
#  [720, 721, 872],
#  [721, 872, 4],
#  [872, 4, 5],
#  [4, 5, 873],
#  [5, 873, 4],
#  [873, 4, 5],
#  [4, 5, 874],
#  [5, 874, 875],
#  [874, 875, 282],
#  [875, 282, 12],
#  [282, 12, 1],
#  [12, 1, 876],
#  [1, 876, 146],
#  [876, 146, 12],
#  [146, 12, 1],
#  [12, 1, 263],
#  [1, 263, 262],
#  [263, 262, 180],
#  [262, 180, 128],
#  [180, 128, 22],
#  [128, 22, 33],
#  [22, 33, 25],
#  [33, 25, 24],
#  [25, 24, 22],
#  [24, 22, 5],
#  [22, 5, 150],
#  [5, 150, 22],
#  [150, 22, 5],
#  [22, 5, 194],
#  [5, 194, 22],
#  [194, 22, 5],
#  [22, 5, 877],
#  [5, 877, 11],
#  [877, 11, 413],
#  [11, 413, 22],
#  [413, 22, 522],
#  [22, 522, 166],
#  [522, 166, 1516],
#  [166, 1516, 126],
#  [1516, 126, 178],
#  [126, 178, 250],
#  [178, 250, 1],
#  [250, 1, 126],
#  [1, 126, 79],
#  [126, 79, 152],
#  [79, 152, 1],
#  [152, 1, 264],
#  [1, 264, 13],
#  [264, 13, 23],
#  [13, 23, 414],
#  [23, 414, 82],
#  [414, 82, 97],
#  [82, 97, 3],
#  [97, 3, 106],
#  [3, 106, 26],
#  [106, 26, 3],
#  [26, 3, 24],
#  [3, 24, 67],
#  [24, 67, 20],
#  [67, 20, 858],
#  [20, 858, 284],
#  [858, 284, 77],
#  [284, 77, 52],
#  [77, 52, 26],
#  [52, 26, 3],
#  [26, 3, 1517],
#  [3, 1517, 719],
#  [1517, 719, 412],
#  [719, 412, 12],
#  [412, 12, 1],
#  [12, 1, 871],
#  [1, 871, 463],
#  [871, 463, 16],
#  [463, 16, 4],
#  [16, 4, 203],
#  [4, 203, 97],
#  [203, 97, 720],
#  [97, 720, 721],
#  [720, 721, 872],
#  [721, 872, 4],
#  [872, 4, 5],
#  [4, 5, 873],
#  [5, 873, 4],
#  [873, 4, 5],
#  [4, 5, 874],
#  [5, 874, 875],
#  [874, 875, 282],
#  [875, 282, 1118],
#  [282, 1118, 12],
#  [1118, 12, 1],
#  [12, 1, 876],
#  [1, 876, 146],
#  [876, 146, 12],
#  [146, 12, 1],
#  [12, 1, 263],
#  [1, 263, 262],
#  [263, 262, 180],
#  [262, 180, 128],
#  [180, 128, 22],
#  [128, 22, 33],
#  [22, 33, 25],
#  [33, 25, 24],
#  [25, 24, 22],
#  [24, 22, 5],
#  [22, 5, 150],
#  [5, 150, 22],
#  [150, 22, 5],
#  [22, 5, 194],
#  [5, 194, 22],
#  [194, 22, 5],
#  [22, 5, 877],
#  [5, 877, 11],
#  [877, 11, 413],
#  [11, 413, 22],
#  [413, 22, 522],
#  [22, 522, 166],
#  [522, 166, 522],
#  [5, 43, 52],
#  [43, 52, 415],
#  [52, 415, 197],
#  [415, 197, 223],
#  [197, 223, 20],
#  [223, 20, 373],
#  [20, 373, 416],
#  [373, 416, 23],
#  [416, 23, 224],
#  [23, 224, 24],
#  [224, 24, 30],
#  [24, 30, 2],
#  [30, 2, 80],
#  [2, 80, 6],
#  [80, 6, 58],
#  [6, 58, 48],
#  [58, 48, 90],
#  [48, 90, 74],
#  [90, 74, 212],
#  [74, 212, 13],
#  [212, 13, 344],
#  [13, 344, 29],
#  [344, 29, 5],
#  [29, 5, 43],
#  [5, 43, 173],
#  [43, 173, 1518],
#  [173, 1518, 139],
#  [1518, 139, 5],
#  [139, 5, 1519],
#  [5, 1519, 188],
#  [1519, 188, 236],
#  [188, 236, 4],
#  [236, 4, 20],
#  [4, 20, 38],
#  [20, 38, 618],
#  [38, 618, 147],
#  [618, 147, 70],
#  [147, 70, 2],
#  [70, 2, 21],
#  [2, 21, 152],
#  [21, 152, 212],
#  [152, 212, 34],
#  [212, 34, 3],
#  [34, 3, 251],
#  [3, 251, 2],
#  [251, 2, 55],
#  [2, 55, 3],
#  [55, 3, 1119],
#  [3, 1119, 23],
#  [1119, 23, 3],
#  [23, 3, 80],
#  [3, 80, 8],
#  [80, 8, 6],
#  [8, 6, 197],
#  [6, 197, 72],
#  [197, 72, 42],
#  [72, 42, 619],
#  [42, 619, 11],
#  [619, 11, 1120],
#  [11, 1120, 2],
#  [1120, 2, 45],
#  [2, 45, 19],
#  [45, 19, 118],
#  [19, 118, 417],
#  [118, 417, 1121],
#  [417, 1121, 525],
#  [1121, 525, 17],
#  [525, 17, 3],
#  [17, 3, 878],
#  [3, 878, 38],
#  [878, 38, 1122],
#  [38, 1122, 53],
#  [1122, 53, 52],
#  [53, 52, 23],
#  [52, 23, 3],
#  [23, 3, 374],
#  [3, 374, 128],
#  [374, 128, 118],
#  [128, 118, 299],
#  [118, 299, 48],
#  [299, 48, 90],
#  [48, 90, 525],
#  [90, 525, 1123],
#  [525, 1123, 119],
#  [1123, 119, 1124],
#  [119, 1124, 9],
#  [1124, 9, 57],
#  ...]

# %% [markdown]
# ### make all senteances of equal length (pad them with space - keras req.)

# %%
# pad sequences to equal lenth (Keras requirement)
max_length = max([len(seq) for seq in sequences])
sequences = pad_sequences(sequences, maxlen=max_length, padding='pre')
print('Max Sequence Length: %d' % max_length)
# Out:
# Max Sequence Length: 3

# %% [markdown]
# ## Get the word embeddings from GLOVE and add them to local memory

# %%
# load the whole embedding into memory
embeddings_index = dict()
f = open('./glove.6B.100d.txt')
for line in f:
	values = line.split()
	word = values[0]
	coefs = numpy.asarray(values[1:], dtype='float32')
	embeddings_index[word] = coefs
f.close()
print('Loaded %s word vectors.' % len(embeddings_index))
# Out:
# Loaded 400001 word vectors.

# %% [markdown]
# ## create weight matrix for glove embeddings

# %%
# create a weight matrix for words in training docs
embedding_matrix = numpy.zeros((vocab_size, 100))
for word, i in  tokenizer.word_index.items():
	embedding_vector = embeddings_index.get(word)
	if embedding_vector is not None:
		embedding_matrix[i] = embedding_vector

# %% [markdown]
# ### prepare data and labels for model

# %%
# convert to numpy and split into data (triples) and labels (target word)
sequences = numpy.array(sequences)
testData, testLabels = sequences[:,:-1],sequences[:,-1]

# one hot encode outputs -> Converts a class vector (integers) to binary class matrix.
testLabels= to_categorical(testLabels, num_classes=vocab_size)

# %% [markdown]
# ### define and fit the model

# %%
# define model
e = Embedding(vocab_size, 100, weights=[embedding_matrix], input_length=max_length-1, trainable=False)
model = Sequential()
model.add(e)
model.add(LSTM(100))
model.add(Dense(vocab_size, activation='softmax'))
print(model.summary())
# compile network
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# fit network
model.fit(testData, testLabels, epochs=100, verbose=2)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 2, 100)            280300
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 100)               80400
# _________________________________________________________________
# dense_1 (Dense)              (None, 2803)              283103
# =================================================================
# Total params: 643,803
# Trainable params: 363,503
# Non-trainable params: 280,300
# _________________________________________________________________
# None
# Epoch 1/100
# 793/793 - 5s - loss: 6.3286 - accuracy: 0.0513
# Epoch 2/100
# 793/793 - 3s - loss: 5.7974 - accuracy: 0.0718
# Epoch 3/100
# 793/793 - 3s - loss: 5.4601 - accuracy: 0.0933
# Epoch 4/100
# 793/793 - 3s - loss: 5.1506 - accuracy: 0.1117
# Epoch 5/100
# 793/793 - 3s - loss: 4.8614 - accuracy: 0.1311
# Epoch 6/100
# 793/793 - 3s - loss: 4.5920 - accuracy: 0.1529
# Epoch 7/100
# 793/793 - 3s - loss: 4.3410 - accuracy: 0.1768
# Epoch 8/100
# 793/793 - 3s - loss: 4.1074 - accuracy: 0.2052
# Epoch 9/100
# 793/793 - 3s - loss: 3.8943 - accuracy: 0.2312
# Epoch 10/100
# 793/793 - 3s - loss: 3.7006 - accuracy: 0.2578
# Epoch 11/100
# 793/793 - 3s - loss: 3.5257 - accuracy: 0.2827
# Epoch 12/100
# 793/793 - 3s - loss: 3.3693 - accuracy: 0.3078
# Epoch 13/100
# 793/793 - 3s - loss: 3.2280 - accuracy: 0.3294
# Epoch 14/100
# 793/793 - 3s - loss: 3.1006 - accuracy: 0.3485
# Epoch 15/100
# 793/793 - 3s - loss: 2.9855 - accuracy: 0.3642
# Epoch 16/100
# 793/793 - 3s - loss: 2.8818 - accuracy: 0.3827
# Epoch 17/100
# 793/793 - 4s - loss: 2.7858 - accuracy: 0.3955
# Epoch 18/100
# 793/793 - 4s - loss: 2.6978 - accuracy: 0.4084
# Epoch 19/100
# 793/793 - 3s - loss: 2.6180 - accuracy: 0.4226
# Epoch 20/100
# 793/793 - 3s - loss: 2.5414 - accuracy: 0.4349
# Epoch 21/100
# 793/793 - 5s - loss: 2.4730 - accuracy: 0.4464
# Epoch 22/100
# 793/793 - 4s - loss: 2.4094 - accuracy: 0.4544
# Epoch 23/100
# 793/793 - 4s - loss: 2.3481 - accuracy: 0.4639
# Epoch 24/100
# 793/793 - 3s - loss: 2.2919 - accuracy: 0.4744
# Epoch 25/100
# 793/793 - 3s - loss: 2.2393 - accuracy: 0.4823
# Epoch 26/100
# 793/793 - 3s - loss: 2.1896 - accuracy: 0.4911
# Epoch 27/100
# 793/793 - 3s - loss: 2.1420 - accuracy: 0.4959
# Epoch 28/100
# 793/793 - 3s - loss: 2.0974 - accuracy: 0.5012
# Epoch 29/100
# 793/793 - 3s - loss: 2.0561 - accuracy: 0.5105
# Epoch 30/100
# 793/793 - 3s - loss: 2.0155 - accuracy: 0.5175
# Epoch 31/100
# 793/793 - 3s - loss: 1.9792 - accuracy: 0.5207
# Epoch 32/100
# 793/793 - 3s - loss: 1.9423 - accuracy: 0.5280
# Epoch 33/100
# 793/793 - 3s - loss: 1.9088 - accuracy: 0.5319
# Epoch 34/100
# 793/793 - 3s - loss: 1.8759 - accuracy: 0.5369
# Epoch 35/100
# 793/793 - 4s - loss: 1.8453 - accuracy: 0.5431
# Epoch 36/100
# 793/793 - 4s - loss: 1.8159 - accuracy: 0.5460
# Epoch 37/100
# 793/793 - 4s - loss: 1.7879 - accuracy: 0.5524
# Epoch 38/100
# 793/793 - 3s - loss: 1.7606 - accuracy: 0.5557
# Epoch 39/100
# 793/793 - 4s - loss: 1.7335 - accuracy: 0.5619
# Epoch 40/100
# 793/793 - 3s - loss: 1.7106 - accuracy: 0.5649
# Epoch 41/100
# 793/793 - 3s - loss: 1.6860 - accuracy: 0.5700
# Epoch 42/100
# 793/793 - 3s - loss: 1.6659 - accuracy: 0.5713
# Epoch 43/100
# 793/793 - 3s - loss: 1.6437 - accuracy: 0.5758
# Epoch 44/100
# 793/793 - 4s - loss: 1.6223 - accuracy: 0.5798
# Epoch 45/100
# 793/793 - 4s - loss: 1.6025 - accuracy: 0.5838
# Epoch 46/100
# 793/793 - 3s - loss: 1.5834 - accuracy: 0.5855
# Epoch 47/100
# 793/793 - 4s - loss: 1.5676 - accuracy: 0.5888
# Epoch 48/100
# 793/793 - 4s - loss: 1.5481 - accuracy: 0.5917
# Epoch 49/100
# 793/793 - 4s - loss: 1.5303 - accuracy: 0.5946
# Epoch 50/100
# 793/793 - 3s - loss: 1.5150 - accuracy: 0.5977
# Epoch 51/100
# 793/793 - 3s - loss: 1.4997 - accuracy: 0.5980
# Epoch 52/100
# 793/793 - 3s - loss: 1.4839 - accuracy: 0.6011
# Epoch 53/100
# 793/793 - 3s - loss: 1.4707 - accuracy: 0.6047
# Epoch 54/100
# 793/793 - 3s - loss: 1.4574 - accuracy: 0.6050
# Epoch 55/100
# 793/793 - 3s - loss: 1.4437 - accuracy: 0.6074
# Epoch 56/100
# 793/793 - 3s - loss: 1.4323 - accuracy: 0.6134
# Epoch 57/100
# 793/793 - 6s - loss: 1.4180 - accuracy: 0.6112
# Epoch 58/100
# 793/793 - 6s - loss: 1.4043 - accuracy: 0.6139
# Epoch 59/100
# 793/793 - 6s - loss: 1.3954 - accuracy: 0.6161
# Epoch 60/100
# 793/793 - 5s - loss: 1.3838 - accuracy: 0.6171
# Epoch 61/100
# 793/793 - 4s - loss: 1.3734 - accuracy: 0.6181
# Epoch 62/100
# 793/793 - 3s - loss: 1.3629 - accuracy: 0.6191
# Epoch 63/100
# 793/793 - 3s - loss: 1.3514 - accuracy: 0.6190
# Epoch 64/100
# 793/793 - 4s - loss: 1.3422 - accuracy: 0.6224
# Epoch 65/100
# 793/793 - 5s - loss: 1.3325 - accuracy: 0.6226
# Epoch 66/100
# 793/793 - 4s - loss: 1.3235 - accuracy: 0.6224
# Epoch 67/100
# 793/793 - 4s - loss: 1.3162 - accuracy: 0.6262
# Epoch 68/100
# 793/793 - 5s - loss: 1.3072 - accuracy: 0.6256
# Epoch 69/100
# 793/793 - 4s - loss: 1.2991 - accuracy: 0.6262
# Epoch 70/100
# 793/793 - 5s - loss: 1.2904 - accuracy: 0.6282
# Epoch 71/100
# 793/793 - 4s - loss: 1.2822 - accuracy: 0.6281
# Epoch 72/100
# 793/793 - 4s - loss: 1.2757 - accuracy: 0.6292
# Epoch 73/100
# 793/793 - 4s - loss: 1.2678 - accuracy: 0.6312
# Epoch 74/100
# 793/793 - 4s - loss: 1.2621 - accuracy: 0.6314
# Epoch 75/100
# 793/793 - 3s - loss: 1.2559 - accuracy: 0.6322
# Epoch 76/100
# 793/793 - 4s - loss: 1.2489 - accuracy: 0.6315
# Epoch 77/100
# 793/793 - 3s - loss: 1.2426 - accuracy: 0.6335
# Epoch 78/100
# 793/793 - 4s - loss: 1.2354 - accuracy: 0.6337
# Epoch 79/100
# 793/793 - 3s - loss: 1.2322 - accuracy: 0.6320
# Epoch 80/100
# 793/793 - 4s - loss: 1.2239 - accuracy: 0.6337
# Epoch 81/100
# 793/793 - 4s - loss: 1.2192 - accuracy: 0.6339
# Epoch 82/100
# 793/793 - 4s - loss: 1.2134 - accuracy: 0.6380
# Epoch 83/100
# 793/793 - 3s - loss: 1.2081 - accuracy: 0.6353
# Epoch 84/100
# 793/793 - 3s - loss: 1.2033 - accuracy: 0.6360
# Epoch 85/100
# 793/793 - 4s - loss: 1.1996 - accuracy: 0.6374
# Epoch 86/100
# 793/793 - 4s - loss: 1.1938 - accuracy: 0.6362
# Epoch 87/100
# 793/793 - 4s - loss: 1.1894 - accuracy: 0.6354
# Epoch 88/100
# 793/793 - 4s - loss: 1.1843 - accuracy: 0.6369
# Epoch 89/100
# 793/793 - 3s - loss: 1.1794 - accuracy: 0.6366
# Epoch 90/100
# 793/793 - 3s - loss: 1.1769 - accuracy: 0.6379
# Epoch 91/100
# 793/793 - 4s - loss: 1.1725 - accuracy: 0.6364
# Epoch 92/100
# 793/793 - 4s - loss: 1.1680 - accuracy: 0.6407
# Epoch 93/100
# 793/793 - 4s - loss: 1.1639 - accuracy: 0.6394
# Epoch 94/100
# 793/793 - 3s - loss: 1.1607 - accuracy: 0.6375
# Epoch 95/100
# 793/793 - 4s - loss: 1.1569 - accuracy: 0.6408
# Epoch 96/100
# 793/793 - 4s - loss: 1.1539 - accuracy: 0.6378
# Epoch 97/100
# 793/793 - 4s - loss: 1.1494 - accuracy: 0.6408
# Epoch 98/100
# 793/793 - 4s - loss: 1.1471 - accuracy: 0.6384
# Epoch 99/100
# 793/793 - 4s - loss: 1.1423 - accuracy: 0.6408
# Epoch 100/100
# 793/793 - 3s - loss: 1.1401 - accuracy: 0.6410

# %% [markdown]
# ### method to generate sequences of text from model

# %%
# generate a sequence from a language model
def generate_seq(model, tokenizer, max_length, seed_text, n_words):
	in_text = seed_text
	# generate a fixed number of words
	for _ in range(n_words):
		# encode the text as integer
		encoded = tokenizer.texts_to_sequences([in_text])[0]
		# pre-pad sequences to a fixed length
		encoded = pad_sequences([encoded], maxlen=max_length, padding='pre')
		# predict probabilities for each word
		yhat = numpy.argmax(model.predict(encoded), axis=-1)
		# map predicted word index to word
		out_word = ''
		for word, index in tokenizer.word_index.items():
			if index == yhat:
				out_word = word
				break
		# append to input
		in_text += ' ' + out_word
	return in_text

# %%
import random

def getSentanceStarter(sentanceStarterLenth, songs):
    randomSongUpperBound = len(songs)
    #
    randomSongIndex = random.randint(0, randomSongUpperBound-1)
    randomSong = songs[randomSongIndex]
    splitSong = randomSong.split("\n")
    randomLineIndex = random.randint(0, len(splitSong)-1)
    line = splitSong[randomLineIndex]
    splitLine = line.split(" ")
    joinedSelection = " ".join(splitLine[0:sentanceStarterLenth])
    return joinedSelection

# %%
# print(generate_seq(model, tokenizer, "I", 6))
print(generate_seq(model, tokenizer, max_length-1, "if i", 100))
# Out:
# if i didn't love you if i didn't love you if i didn't love you if i didn't love you if i didn't love you if i didn't love you if i didn't love you if i didn't love you if i didn't love you if i didn't love you if i didn't love you if i didn't love you if i didn't love you if i didn't love you if i didn't love you if i didn't love you if i didn't love you if i didn't love you if i didn't love you if i didn't love you if i

# %% [markdown]
# ## eval with BLEU score
# https://towardsdatascience.com/how-to-evaluate-texxt-generation-models-metrics-for-automatic-evaluation-of-nlp-models-e1c251b04ec1

# %%
from nltk.translate.bleu_score import SmoothingFunction, corpus_bleu, sentence_bleu


def bleu(ref, gen):
    ''' 
    calculate pair wise bleu score. uses nltk implementation
    Args:
        references : a list of reference sentences 
        candidates : a list of candidate(generated) sentences
    Returns:
        bleu score(float)
    '''
    ref_bleu = []
    gen_bleu = []
    for l in gen:
        gen_bleu.append(l.split())
    for i,l in enumerate(ref):
        ref_bleu.append([l.split()])
    cc = SmoothingFunction()
    score_bleu = corpus_bleu(ref_bleu, gen_bleu, weights=(0, 1, 0, 0), smoothing_function=cc.method4)
    return score_bleu

# %%
bleu(["It's hittin' rock bottom smoke 'em if you got 'em"],["nothing's going right makin' i just wish you were a"])
# Out:
# 0.025584278811044955
